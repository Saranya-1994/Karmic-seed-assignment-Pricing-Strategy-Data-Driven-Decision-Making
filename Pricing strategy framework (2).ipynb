# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pricing = pd.read_csv('C:/Users/saranya cj/Downloads/Pricing_Data.csv')
inventory = pd.read_csv('C:/Users/saranya cj/Downloads/Inventory_Health.csv')
ads = pd.read_csv('C:/Users/saranya cj/Downloads/Ads_Performance.csv')
competitor_data = pd.read_csv('C:/Users/saranya cj/Downloads/Competitor_Data.csv')
Historical_sales = pd.read_csv('C:/Users/saranya cj/Downloads/Historical_Sales.csv')

# %%
## next cleaning data sets# Clean currency and percentage symbols to make them numbers#

# %%
pricing['Cost'] = pd.to_numeric(
    pricing['Cost'].astype(str).str.replace('$', '', regex=False),
    errors='coerce')
pricing ['Current_Price'] =pricing ['Current_Price'].str.replace('$','').astype(float)
pricing ['Minimum_margin'] = pricing['Minimum_Acceptable_Margin_%'].str.replace('%', '').astype(float) / 100

# %%
# Merge into one master dataframe

# %%
df= pricing.merge(inventory, on='SKU', how ='left')
df=df.merge(competitor_data, on='SKU', how ='left')

# %%
df.head

# %%
df.info

# %%
df.isnull().sum()
# Out:
# SKU                            0
# Product_description            0
# Product Role                   0
# Country_of_Origin              0
# FBA Fee                        0
# Storage Fee                    0
# Handling_Cost                  0
# Cost                           0
# Current_Price                  0
# Minimum_Acceptable_Margin_%    0
# Target_Gross_Margin_%          0
# Minimum_margin                 0
# Sessions - Total               0
# Units Ordered                  0
# Ordered Product Sales          0
# Total Order Items              0
# demand_signal                  0
# days-of-supply                 0
# inventory_signal               0
# spend                          0
# acosClicks7d                   0
# ads_signal                     0
# Highest_Competitor_Price       0
# dtype: int64

# %%
##Describe ALL columns

# %%
df.describe(include='all')
# Out:
#           SKU                       Product_description Product Role  \
# count      50                                        50           50
# unique     50                                        50            2
# top     MN-01  Rectangle Tray -14 x 10 Inch - Pk of  25         Core
# freq        1                                         1           46
# mean      NaN                                       NaN          NaN
# std       NaN                                       NaN          NaN
# min       NaN                                       NaN          NaN
# 25%       NaN                                       NaN          NaN
# 50%       NaN                                       NaN          NaN
# 75%       NaN                                       NaN          NaN
# max       NaN                                       NaN          NaN
#
#        Country_of_Origin FBA Fee Storage Fee Handling_Cost       Cost  \
# count                 50      50          50            50  50.000000
# unique                 1      46          32             2        NaN
# top                India  $12.89       $0.30         $0.75        NaN
# freq                  50       2           4            49        NaN
# mean                 NaN     NaN         NaN           NaN  12.600000
# std                  NaN     NaN         NaN           NaN   8.422516
# min                  NaN     NaN         NaN           NaN   3.000000
# 25%                  NaN     NaN         NaN           NaN   7.000000
# 50%                  NaN     NaN         NaN           NaN  11.500000
# 75%                  NaN     NaN         NaN           NaN  14.000000
# max                  NaN     NaN         NaN           NaN  44.000000
#
#         Current_Price Minimum_Acceptable_Margin_%  ... Units Ordered  \
# count       50.000000                          50  ...     50.000000
# unique            NaN                           2  ...           NaN
# top               NaN                         20%  ...           NaN
# freq              NaN                          46  ...           NaN
# mean        30.102000                         NaN  ...    804.680000
# std         16.449344                         NaN  ...    824.930806
# min          9.950000                         NaN  ...     43.000000
# 25%         21.900000                         NaN  ...    283.500000
# 50%         27.900000                         NaN  ...    481.500000
# 75%         32.650000                         NaN  ...   1193.000000
# max         89.900000                         NaN  ...   4471.000000
#
#         Ordered Product Sales  Total Order Items  demand_signal  \
# count               50.000000           50.00000             50
# unique                    NaN                NaN              2
# top                       NaN                NaN           high
# freq                      NaN                NaN             25
# mean             26852.829400          592.92000            NaN
# std              32166.069315          616.15519            NaN
# min               1300.990000           35.00000            NaN
# 25%               7725.412500          195.00000            NaN
# 50%              13856.075000          395.00000            NaN
# 75%              32106.410000          650.00000            NaN
# max             162093.760000         3059.00000            NaN
#
#         days-of-supply  inventory_signal         spend  acosClicks7d  \
# count        50.000000                50     50.000000     50.000000
# unique             NaN                 3           NaN           NaN
# top                NaN           healthy           NaN           NaN
# freq               NaN                35           NaN           NaN
# mean         77.600000               NaN   3457.929400     26.118222
# std          31.653739               NaN   4617.222467     12.160356
# min           0.000000               NaN    194.110000      4.614372
# 25%          63.250000               NaN   1089.580000     18.191715
# 50%          79.500000               NaN   2017.360000     24.113521
# 75%          89.750000               NaN   3891.327500     31.791817
# max         159.000000               NaN  28107.190000     77.141743
#
#          ads_signal  Highest_Competitor_Price
# count            50                 50.000000
# unique            2                       NaN
# top     inefficient                       NaN
# freq             25                       NaN
# mean            NaN                 38.724000
# std             NaN                 20.769123
# min             NaN                  0.000000
# 25%             NaN                 28.400000
# 50%             NaN                 36.900000
# 75%             NaN                 41.412500
# max             NaN                109.900000
#
# [11 rows x 23 columns]

# %%
##Describe only numeric columns

# %%
df.describe(include='number')
# Out:
#             Cost  Current_Price  Minimum_margin  Sessions - Total  \
# count  50.000000      50.000000       50.000000         50.000000
# mean   12.600000      30.102000        0.204000       2735.980000
# std     8.422516      16.449344        0.013702       2570.315938
# min     3.000000       9.950000        0.200000        168.000000
# 25%     7.000000      21.900000        0.200000        971.500000
# 50%    11.500000      27.900000        0.200000       1919.000000
# 75%    14.000000      32.650000        0.200000       3241.500000
# max    44.000000      89.900000        0.250000      10412.000000
#
#        Units Ordered  Ordered Product Sales  Total Order Items  \
# count      50.000000              50.000000           50.00000
# mean      804.680000           26852.829400          592.92000
# std       824.930806           32166.069315          616.15519
# min        43.000000            1300.990000           35.00000
# 25%       283.500000            7725.412500          195.00000
# 50%       481.500000           13856.075000          395.00000
# 75%      1193.000000           32106.410000          650.00000
# max      4471.000000          162093.760000         3059.00000
#
#        days-of-supply         spend  acosClicks7d  Highest_Competitor_Price
# count       50.000000     50.000000     50.000000                 50.000000
# mean        77.600000   3457.929400     26.118222                 38.724000
# std         31.653739   4617.222467     12.160356                 20.769123
# min          0.000000    194.110000      4.614372                  0.000000
# 25%         63.250000   1089.580000     18.191715                 28.400000
# 50%         79.500000   2017.360000     24.113521                 36.900000
# 75%         89.750000   3891.327500     31.791817                 41.412500
# max        159.000000  28107.190000     77.141743                109.900000

# %%
## DATA TYPES CHECK

# %%
df[['Cost', 'FBA Fee', 'Storage Fee', 'Handling_Cost']].dtypes
# Out:
# Cost             float64
# FBA Fee           object
# Storage Fee       object
# Handling_Cost     object
# dtype: object

# %%
cost_cols = ['Cost', 'FBA Fee', 'Storage Fee', 'Handling_Cost']

for col in cost_cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace('$', '', regex=False)
        .str.replace(',', '', regex=False)
        .str.strip()
    )
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# CALCULATE THE TRUE UNIT (landed price)

# %%
df['True_Unit_Cost'] = df[cost_cols].sum(axis=1)

# %%
df['True_Unit_Cost'].describe
# Out:
# <bound method NDFrame.describe of 0     32.30
# 1     26.60
# 2     30.03
# 3     25.94
# 4     25.77
# 5     14.37
# 6     29.87
# 7     26.11
# 8     14.92
# 9     17.40
# 10    15.26
# 11    17.87
# 12    17.80
# 13    24.93
# 14    19.24
# 15    17.40
# 16    27.98
# 17    27.73
# 18    32.94
# 19    11.02
# 20    19.40
# 21    19.08
# 22    10.40
# 23    15.62
# 24    31.21
# 25    26.85
# 26    24.18
# 27    22.47
# 28    17.71
# 29    35.23
# 30    26.55
# 31    23.91
# 32    22.16
# 33    28.44
# 34    28.49
# 35    25.05
# 36    25.92
# 37    25.54
# 38    22.93
# 39    19.67
# 40    63.42
# 41    50.79
# 42    10.81
# 43     9.66
# 44    25.68
# 45    20.99
# 46    55.34
# 47    68.98
# 48    30.56
# 49    27.60
# Name: True_Unit_Cost, dtype: float64>

# %%
df['Minimum_Acceptable_Margin_%'].dtype
# Out:
# dtype('O')

# %%
df['Floor_Price'] = df['True_Unit_Cost'] * (  1 + df['Minimum_Acceptable_Margin_%'] / 100
)
df[['SKU',
    'True_Unit_Cost',
    'Floor_Price',
    'target_price',
    'Highest_Competitor_Price'
]].head()
# Out:
#      SKU  True_Unit_Cost  Floor_Price  target_price  Highest_Competitor_Price
# 0  MN-01           32.30      38.7600       43.6050                     44.90
# 1  MN-02           26.60      31.9200       35.9100                     39.95
# 2  MN-03           30.03      36.0360       40.5405                     42.50
# 3  MN-04           25.94      31.1280       35.0190                     35.90
# 4  MN-05           25.77      32.2125       37.3665                      0.00

# %%
df['Minimum_Acceptable_Margin_%'] = (
    df['Minimum_Acceptable_Margin_%']
    .astype(str)
    .str.replace('%', '', regex=False)
    .astype(float)
)

df['Target_Gross_Margin_%'] = (  
    df['Target_Gross_Margin_%']
     .astype(str)
    .str.replace('%', '', regex=False)
    .str.strip()
    .astype(float)
)

# %%
## Set minimum and Target price
 ## This satisfies margin protection, a core business requirement.

# %%
df.columns
# Out:
# Index(['SKU', 'Product_description', 'Product Role', 'Country_of_Origin',
#        'FBA Fee', 'Storage Fee', 'Handling_Cost', 'Cost', 'Current_Price',
#        'Minimum_Acceptable_Margin_%', 'Target_Gross_Margin_%',
#        'Minimum_margin', 'condition', 'total-inventory', 'available',
#        'inbound-shipped', 'inbound-received', 'reserved-quantity',
#        'unfulfillable-quantity', 'inv-age-0-to-30-days',
#        'inv-age-31-to-60-days', 'inv-age-61-to-90-days',
#        'inv-age-181-to-330-days', 'inv-age-331-to-365-days',
#        'inv-age-365-plus-days', 'currency', 'units-shipped-t7',
#        'units-shipped-t30', 'units-shipped-t60', 'units-shipped-t90',
#        'sell-through', 'item-volume', 'volume-unit-measurement',
#        'storage-type', 'storage-volume', 'marketplace', 'days-of-supply',
#        'weeks-of-cover-t30', 'weeks-of-cover-t90', 'Avg_Competitor_Price',
#        'Lowest_Competitor_Price', 'Highest_Competitor_Price',
#        'Competitor_Count', 'True_Unit_Cost', 'Floor_Price'],
#       dtype='object')

# %%
df['min_price'] = df['True_Unit_Cost'] * (1 +df['Minimum_Acceptable_Margin_%']/100)
df["target_price"] = df["True_Unit_Cost"] * (1 + df["Target_Gross_Margin_%"]/100)
df[['SKU', 'True_Unit_Cost', 'min_price', 'target_price']].head()
# Out:
#      SKU  True_Unit_Cost  min_price  target_price
# 0  MN-01           32.30    38.7600       43.6050
# 1  MN-02           26.60    31.9200       35.9100
# 2  MN-03           30.03    36.0360       40.5405
# 3  MN-04           25.94    31.1280       35.0190
# 4  MN-05           25.77    32.2125       37.3665

# %%
## demand signal

# %%
Historical_sales["demand_signal"] = Historical_sales["Units Ordered"].apply(
    lambda x: "high" if x > Historical_sales["Units Ordered"].median() else "low"
)

# %%
Historical_sales.head(10)
# Out:
#          Date    SKU  Sessions - Total  Page Views - Total  Units Ordered  \
# 0  01/09/2025  MN-01              22.0                32.0            6.0
# 1  01/09/2025  MN-02              28.0                33.0            5.0
# 2  01/09/2025  MN-03               9.0                12.0            2.0
# 3  01/09/2025  MN-07              31.0                41.0            2.0
# 4  01/09/2025  MN-09              24.0                32.0            2.0
# 5  01/09/2025  MN-10              10.0                11.0            1.0
# 6  01/09/2025  MN-13              27.0                44.0            5.0
# 7  01/09/2025  MN-14              28.0                49.0            5.0
# 8  01/09/2025  MN-15              88.0               107.0           21.0
# 9  01/09/2025  MN-16              27.0                39.0            4.0
#
#    Ordered Product Sales  Total Order Items demand_signal
# 0                 228.10                5.0          high
# 1                 158.96                5.0           low
# 2                  81.35                2.0           low
# 3                  70.11                2.0           low
# 4                  32.26                1.0           low
# 5                  23.15                1.0           low
# 6                 106.44                5.0           low
# 7                 152.47                5.0           low
# 8                 466.71               18.0          high
# 9                  70.67                4.0           low

# %%
##Create Inventory Signal

# %%
inventory["inventory_signal"] = inventory["days-of-supply"].apply(
    lambda x: "low_stock" if x < 15 else "healthy"
)
inventory.head()
# Out:
#      SKU condition  total-inventory  available  inbound-shipped  \
# 0  MN-01       New            382.0        264               40
# 1  MN-02       New            306.0        206               80
# 2  MN-03       New            139.0         95               40
# 3  MN-04       New            171.0         70               80
# 4  MN-05       New            283.0          0                0
#
#    inbound-received  reserved-quantity  unfulfillable-quantity  \
# 0                 9                 68                       1
# 1                 2                 18                       0
# 2                 0                  3                       1
# 3                 8                 13                       0
# 4                49                234                       0
#
#    inv-age-0-to-30-days  inv-age-31-to-60-days  ...  sell-through  \
# 0                    12                    261  ...          1.33
# 1                   127                     91  ...          1.56
# 2                    42                      8  ...          1.16
# 3                     3                     84  ...          1.65
# 4                    53                    141  ...          1.47
#
#    item-volume  volume-unit-measurement  storage-type storage-volume  \
# 0     0.546781               cubic feet      Standard     144.350184
# 1     0.373971               cubic feet      Standard      77.038026
# 2     0.425846               cubic feet      Standard      40.455370
# 3     0.375575               cubic feet      Standard      26.290250
# 4     0.270417               cubic feet      Standard       0.000000
#
#    marketplace  days-of-supply  weeks-of-cover-t30  weeks-of-cover-t90  \
# 0           US              47                   6                   7
# 1           US              85                   7                   8
# 2           US              83                   8                   9
# 3           US              99                   8                  10
# 4           US             145                   0                   1
#
#    inventory_signal
# 0           healthy
# 1           healthy
# 2           healthy
# 3           healthy
# 4           healthy
#
# [5 rows x 29 columns]

# %%
## adds performance signal

# %%
ads["ads_signal"] = ads["acosClicks7d"].apply(
    lambda x: "inefficient" if x > 0.35 else "efficient"
)
ads.head()
# Out:
#          date    SKU  impressions  clicks  costPerClick  clickThroughRate  \
# 0  2025-09-01  MN-16         2016      14         1.998             0.694
# 1  2025-09-01  MN-15         1810      33         2.062             1.823
# 2  2025-09-01  MN-14          613       9         2.850             1.468
# 3  2025-09-01  MN-17         1271       3         5.620             0.236
# 4  2025-09-01  MN-25         1036      10         4.340             0.965
#
#     cost  spend currency-code  purchases1d  ...  unitsSoldClicks30d  sales1d  \
# 0  27.97  27.97           USD            1  ...                   1    18.89
# 1  68.06  68.06           USD            4  ...                   6   107.45
# 2  25.65  25.65           USD            0  ...                   1     0.00
# 3  16.86  16.86           USD            2  ...                   9   274.41
# 4  43.40  43.40           USD            1  ...                   8   218.30
#
#    sales7d  sales14d  sales30d  acosClicks7d  acosClicks14d  roasClicks7d  \
# 0    18.89     18.89     18.89    148.067761     148.067761      0.675366
# 1   161.31    161.31    161.31     42.192053      42.192053      2.370115
# 2    90.98     90.98     90.98     28.193009      28.193009      3.546979
# 3   274.41    274.41    274.41      6.144091       6.144091     16.275801
# 4   851.24    851.24    851.24      5.098445       5.098445     19.613825
#
#    roasClicks14d   ads_signal
# 0       0.675366  inefficient
# 1       2.370115  inefficient
# 2       3.546979  inefficient
# 3      16.275801  inefficient
# 4      19.613825  inefficient
#
# [5 rows x 26 columns]

# %%
## merge all datasets based on sku level

# %%
df['min_price'] = df['True_Unit_Cost'] * (1 +df['Minimum_Acceptable_Margin_%']/100)
df["target_price"] = df["True_Unit_Cost"] * (1 + df["Target_Gross_Margin_%"]/100)
df[['SKU', 'True_Unit_Cost', 'min_price', 'target_price']].head()
# Out:
#      SKU  True_Unit_Cost  min_price  target_price
# 0  MN-01           32.30    38.7600       43.6050
# 1  MN-02           26.60    31.9200       35.9100
# 2  MN-03           30.03    36.0360       40.5405
# 3  MN-04           25.94    31.1280       35.0190
# 4  MN-05           25.77    32.2125       37.3665

# %%
df.columns
# Out:
# Index(['SKU', 'Product_description', 'Product Role', 'Country_of_Origin',
#        'FBA Fee', 'Storage Fee', 'Handling_Cost', 'Cost', 'Current_Price',
#        'Minimum_Acceptable_Margin_%', 'Target_Gross_Margin_%',
#        'Minimum_margin', 'Sessions - Total', 'Units Ordered',
#        'Ordered Product Sales', 'Total Order Items', 'demand_signal',
#        'days-of-supply', 'inventory_signal', 'spend', 'acosClicks7d',
#        'ads_signal', 'Highest_Competitor_Price'],
#       dtype='object')

# %%
df[['target_price', 'min_price', 'Highest_Competitor_Price']].dtypes
# Out:
# target_price                float64
# min_price                   float64
# Highest_Competitor_Price    float64
# dtype: object

# %%
df['Highest_Competitor_Price'] = (
    df['Highest_Competitor_Price']
    .astype(str)
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    .str.strip()
)

df['Highest_Competitor_Price'] = pd.to_numeric(
    df['Highest_Competitor_Price'],
    errors='coerce'
)
df[['Highest_Competitor_Price']].dtypes

# %%
sales_agg = Historical_sales.groupby("SKU", as_index=False).agg({
    "Sessions - Total": "sum",
    "Units Ordered": "sum",
    "Ordered Product Sales": "sum",
    "Total Order Items": "sum"
})

# %%
sales_agg.info
# Out:
# <bound method DataFrame.info of       SKU  Sessions - Total  Units Ordered  Ordered Product Sales  \
# 0   MN-01            1921.0          587.0               24582.01
# 1   MN-02            1842.0          431.0               15678.89
# 2   MN-03             859.0          196.0                7340.65
# 3   MN-04             604.0          191.0                6002.72
# 4   MN-05            1917.0          341.0                8040.18
# 5   MN-06             562.0          124.0                1978.61
# 6   MN-07            1815.0          236.0                8815.03
# 7   MN-08             168.0           43.0                1300.99
# 8   MN-09             515.0           81.0                1347.61
# 9   MN-10            1292.0          230.0                5079.01
# 10  MN-11            1762.0          236.0                4487.02
# 11  MN-12            2040.0          352.0                7675.78
# 12  MN-13            4116.0          484.0               11960.96
# 13  MN-14            4361.0         1399.0               41676.88
# 14  MN-15           10412.0         2379.0               58379.78
# 15  MN-16            2762.0          490.0               11061.32
# 16  MN-17            3294.0          762.0               23389.16
# 17  MN-18            2579.0          819.0               23184.52
# 18  MN-19            9424.0         1645.0               69270.69
# 19  MN-20           10025.0         1653.0               22784.58
# 20  MN-21            4057.0          583.0               13480.54
# 21  MN-22            3084.0          722.0               16857.39
# 22  MN-23            3042.0          661.0                7706.77
# 23  MN-24            4106.0          479.0               10530.79
# 24  MN-25            9214.0         4471.0              162093.76
# 25  MN-26            2182.0         1663.0               51943.06
# 26  MN-27            1931.0         1257.0               37075.55
# 27  MN-28            4178.0         2480.0               67191.91
# 28  MN-29            4150.0         1519.0               35927.68
# 29  MN-30            2755.0          688.0               25371.02
# 30  MN-31            1166.0          355.0               11109.33
# 31  MN-32            1133.0          533.0               15247.31
# 32  MN-33             927.0          388.0               10415.60
# 33  MN-34            1610.0         1001.0               34351.54
# 34  MN-35            1039.0          417.0               14231.61
# 35  MN-36            8393.0         2255.0               76049.52
# 36  MN-37             845.0          252.0                7781.34
# 37  MN-38            4840.0         1578.0               51402.66
# 38  MN-39             929.0          282.0                7554.45
# 39  MN-40            1767.0          883.0               23039.63
# 40  MN-41            2046.0         1613.0              124522.16
# 41  MN-42            1967.0         1267.0               90693.93
# 42  MN-43            1404.0          207.0                2794.23
# 43  MN-44             949.0          135.0                1653.24
# 44  MN-45             842.0          358.0               11995.80
# 45  MN-46             593.0          173.0                4848.57
# 46  MN-47             635.0          306.0               23508.05
# 47  MN-48             751.0          288.0               25328.42
# 48  MN-49            2191.0          380.0               12951.90
# 49  MN-50            1803.0          361.0               10947.32
#
#     Total Order Items
# 0               475.0
# 1               326.0
# 2               152.0
# 3               126.0
# 4               302.0
# 5               106.0
# 6               221.0
# 7                35.0
# 8                72.0
# 9               201.0
# 10              217.0
# 11              332.0
# 12              451.0
# 13             1058.0
# 14             2169.0
# 15              455.0
# 16              588.0
# 17              571.0
# 18             1546.0
# 19             1484.0
# 20              497.0
# 21              656.0
# 22              632.0
# 23              448.0
# 24             3059.0
# 25              841.0
# 26              831.0
# 27             1727.0
# 28             1094.0
# 29              476.0
# 30              266.0
# 31              342.0
# 32              267.0
# 33              536.0
# 34              282.0
# 35             2122.0
# 36              186.0
# 37              777.0
# 38              193.0
# 39              583.0
# 40              823.0
# 41              626.0
# 42              186.0
# 43              130.0
# 44              167.0
# 45              104.0
# 46              183.0
# 47              187.0
# 48              277.0
# 49              261.0  >

# %%
median_units = sales_agg['Units Ordered'].median()

sales_agg['demand_signal'] = np.where(
    sales_agg['Units Ordered'] > median_units,
    'high',
    'low'
)
sales_agg[['SKU', 'Units Ordered', 'demand_signal']].head()
# Out:
#      SKU  Units Ordered demand_signal
# 0  MN-01          587.0          high
# 1  MN-02          431.0           low
# 2  MN-03          196.0           low
# 3  MN-04          191.0           low
# 4  MN-05          341.0           low

# %%
df = df.merge(
    sales_agg[["SKU", "demand_signal"]],
    on="SKU",
    how="left"
)

# %%
df.head()
# Out:
#      SKU                       Product_description Product Role  \
# 0  MN-01  Rectangle Tray -14 x 10 Inch - Pk of  25         Core
# 1  MN-02          Rectangle Tray -12x10 - Pk of 25         Core
# 2  MN-03         Oval Tray -15x10 Inch - Pk of  25         Core
# 3  MN-04          Oval Tray - 13x9 Inch - pk of 25         Core
# 4  MN-05     Christmas Tray - 17x12 Inch - Pk of 5     Seasonal
#
#   Country_of_Origin  FBA Fee  Storage Fee  Handling_Cost  Cost  Current_Price  \
# 0             India    15.11         0.44           0.75  16.0           38.9
# 1             India    13.55         0.30           0.75  12.0           33.9
# 2             India    13.94         0.34           0.75  15.0           34.9
# 3             India    12.89         0.30           0.75  12.0           29.9
# 4             India    11.80         0.22           0.75  13.0           21.9
#
#    Minimum_Acceptable_Margin_%  ...  weeks-of-cover-t90  Avg_Competitor_Price  \
# 0                         20.0  ...                   7                $36.90
# 1                         20.0  ...                   8                $32.50
# 2                         20.0  ...                   9                $35.20
# 3                         20.0  ...                  10                $28.40
# 4                         25.0  ...                   1                $23.90
#
#   Lowest_Competitor_Price  Highest_Competitor_Price  Competitor_Count  \
# 0                  $31.95                     44.90                 9
# 1                  $27.90                     39.95                 8
# 2                  $29.99                     42.50                 7
# 3                  $24.50                     35.90                 6
# 4                  $18.95                      0.00                 3
#
#    True_Unit_Cost  Floor_Price  min_price  target_price  demand_signal
# 0           32.30      38.7600    38.7600       43.6050           high
# 1           26.60      31.9200    31.9200       35.9100            low
# 2           30.03      36.0360    36.0360       40.5405            low
# 3           25.94      31.1280    31.1280       35.0190            low
# 4           25.77      32.2125    32.2125       37.3665            low
#
# [5 rows x 48 columns]

# %%
inventory_agg = inventory.groupby("SKU", as_index=False).agg({
    "days-of-supply": "mean"
})

# %%
inventory_agg["inventory_signal"] = np.where(
    inventory_agg["days-of-supply"] < 30, "low_inventory",
    np.where(inventory_agg["days-of-supply"] > 90, "overstock", "healthy")
)
inventory_agg[["SKU", "days-of-supply", "inventory_signal"]].head()
# Out:
#      SKU  days-of-supply inventory_signal
# 0  MN-01            47.0          healthy
# 1  MN-02            85.0          healthy
# 2  MN-03            83.0          healthy
# 3  MN-04            99.0        overstock
# 4  MN-05           145.0        overstock

# %%
df = df.drop(
    columns=['inventory_signal_x', 'inventory_signal_y', 'inventory_signal_new'],
    errors='ignore'
)

# %%
df = df.merge(
    inventory_agg[["SKU", "inventory_signal"]],
    on="SKU",
    how="left"
)
df.columns
# Out:
# Index(['SKU', 'Product_description', 'Product Role', 'Country_of_Origin',
#        'FBA Fee', 'Storage Fee', 'Handling_Cost', 'Cost', 'Current_Price',
#        'Minimum_Acceptable_Margin_%', 'Target_Gross_Margin_%',
#        'Minimum_margin', 'condition', 'total-inventory', 'available',
#        'inbound-shipped', 'inbound-received', 'reserved-quantity',
#        'unfulfillable-quantity', 'inv-age-0-to-30-days',
#        'inv-age-31-to-60-days', 'inv-age-61-to-90-days',
#        'inv-age-181-to-330-days', 'inv-age-331-to-365-days',
#        'inv-age-365-plus-days', 'currency', 'units-shipped-t7',
#        'units-shipped-t30', 'units-shipped-t60', 'units-shipped-t90',
#        'sell-through', 'item-volume', 'volume-unit-measurement',
#        'storage-type', 'storage-volume', 'marketplace', 'days-of-supply',
#        'weeks-of-cover-t30', 'weeks-of-cover-t90', 'Avg_Competitor_Price',
#        'Lowest_Competitor_Price', 'Highest_Competitor_Price',
#        'Competitor_Count', 'True_Unit_Cost', 'Floor_Price', 'min_price',
#        'target_price', 'demand_signal', 'inventory_signal'],
#       dtype='object')

# %%
ads_agg = ads.groupby("SKU", as_index=False).agg({
    "spend": "sum",
    "acosClicks7d": "mean"
})
ads_agg.head()
# Out:
#      SKU    spend  acosClicks7d
# 0  MN-01  2762.06     31.491089
# 1  MN-02  2286.92     17.450712
# 2  MN-03   670.20     14.699685
# 3  MN-04   903.79     38.972894
# 4  MN-05   637.85     28.954224

# %%
median_acos = ads_agg["acosClicks7d"].median()

ads_agg["ads_signal"] = np.where(
    ads_agg["acosClicks7d"] <= median_acos,
    "efficient",
    "inefficient"
)
ads_agg[["SKU", "acosClicks7d", "ads_signal"]].head()
# Out:
#      SKU  acosClicks7d   ads_signal
# 0  MN-01     31.491089  inefficient
# 1  MN-02     17.450712    efficient
# 2  MN-03     14.699685    efficient
# 3  MN-04     38.972894  inefficient
# 4  MN-05     28.954224  inefficient

# %%
df = df.drop(columns=["ads_signal_x", "ads_signal_y"], errors="ignore")

# %%
df = df.merge(
    ads_agg[["SKU", "ads_signal"]],
    on="SKU",
    how="left"
)
df.columns
# Out:
# Index(['SKU', 'Product_description', 'Product Role', 'Country_of_Origin',
#        'FBA Fee', 'Storage Fee', 'Handling_Cost', 'Cost', 'Current_Price',
#        'Minimum_Acceptable_Margin_%', 'Target_Gross_Margin_%',
#        'Minimum_margin', 'condition', 'total-inventory', 'available',
#        'inbound-shipped', 'inbound-received', 'reserved-quantity',
#        'unfulfillable-quantity', 'inv-age-0-to-30-days',
#        'inv-age-31-to-60-days', 'inv-age-61-to-90-days',
#        'inv-age-181-to-330-days', 'inv-age-331-to-365-days',
#        'inv-age-365-plus-days', 'currency', 'units-shipped-t7',
#        'units-shipped-t30', 'units-shipped-t60', 'units-shipped-t90',
#        'sell-through', 'item-volume', 'volume-unit-measurement',
#        'storage-type', 'storage-volume', 'marketplace', 'days-of-supply',
#        'weeks-of-cover-t30', 'weeks-of-cover-t90', 'Avg_Competitor_Price',
#        'Lowest_Competitor_Price', 'Highest_Competitor_Price',
#        'Competitor_Count', 'True_Unit_Cost', 'Floor_Price', 'min_price',
#        'target_price', 'demand_signal', 'inventory_signal', 'ads_signal'],
#       dtype='object')

# %%
competitor_agg = competitor_data.groupby("SKU", as_index=False).agg({
    "Highest_Competitor_Price": "max"
})

# %%
df = (
    pricing
    .merge(sales_agg, on="SKU", how="left")
    .merge(inventory_agg, on="SKU", how="left")
    .merge(ads_agg, on="SKU", how="left")
    .merge(competitor_agg, on="SKU", how="left")
)
df.head()
# Out:
#      SKU                       Product_description Product Role  \
# 0  MN-01  Rectangle Tray -14 x 10 Inch - Pk of  25         Core
# 1  MN-02          Rectangle Tray -12x10 - Pk of 25         Core
# 2  MN-03         Oval Tray -15x10 Inch - Pk of  25         Core
# 3  MN-04          Oval Tray - 13x9 Inch - pk of 25         Core
# 4  MN-05     Christmas Tray - 17x12 Inch - Pk of 5     Seasonal
#
#   Country_of_Origin FBA Fee Storage Fee Handling_Cost  Cost  Current_Price  \
# 0             India  $15.11       $0.44         $0.75  16.0           38.9
# 1             India  $13.55       $0.30         $0.75  12.0           33.9
# 2             India  $13.94       $0.34         $0.75  15.0           34.9
# 3             India  $12.89       $0.30         $0.75  12.0           29.9
# 4             India  $11.80       $0.22         $0.75  13.0           21.9
#
#   Minimum_Acceptable_Margin_%  ... Units Ordered  Ordered Product Sales  \
# 0                         20%  ...         587.0               24582.01
# 1                         20%  ...         431.0               15678.89
# 2                         20%  ...         196.0                7340.65
# 3                         20%  ...         191.0                6002.72
# 4                         25%  ...         341.0                8040.18
#
#    Total Order Items  demand_signal  days-of-supply  inventory_signal  \
# 0              475.0           high            47.0           healthy
# 1              326.0            low            85.0           healthy
# 2              152.0            low            83.0           healthy
# 3              126.0            low            99.0         overstock
# 4              302.0            low           145.0         overstock
#
#      spend  acosClicks7d   ads_signal  Highest_Competitor_Price
# 0  2762.06     31.491089  inefficient                    $44.90
# 1  2286.92     17.450712    efficient                    $39.95
# 2   670.20     14.699685    efficient                    $42.50
# 3   903.79     38.972894  inefficient                    $35.90
# 4   637.85     28.954224  inefficient                     $0.00
#
# [5 rows x 23 columns]

# %%
## core rule based pricing

# %%
def pricing_rules(row):
    price =row ['target_price']

    # Demand rule
    if row['demand_signal'] == 'High_Demand':
        price*= 1.05
    else:
        price*= 0.95

    # Inventory rule
    if row['inventory_signal'] == 'Low_Inventory':
        price *= 1.05

    # Ads efficiency rule
    if row['ads_signal'] == 'Inefficient':
        price *= 0.95

    # Guardrails
    price = max(price, row['min_price'])
    price = min(price, row['Highest_Competitor_Price'])

    return round(price, 2)

df["Recommended_New_Price"] = df.apply(pricing_rules, axis=1)

# %%
df[["SKU",
    "target_price",
    "min_price",
    "Highest_Competitor_Price",
    "Floor_Price",
    "Current_Price",
    "Recommended_New_Price",    
]].head(10)
# Out:
#      SKU  target_price  min_price  Highest_Competitor_Price  Floor_Price  \
# 0  MN-01       43.6050    38.7600                     44.90      38.7600
# 1  MN-02       35.9100    31.9200                     39.95      31.9200
# 2  MN-03       40.5405    36.0360                     42.50      36.0360
# 3  MN-04       35.0190    31.1280                     35.90      31.1280
# 4  MN-05       37.3665    32.2125                      0.00      32.2125
# 5  MN-06       20.8365    17.9625                     21.50      17.9625
# 6  MN-07       40.3245    35.8440                     41.95      35.8440
# 7  MN-08       37.8595    32.6375                     39.90      32.6375
# 8  MN-09       21.6340    18.6500                     22.90      18.6500
# 9  MN-10       23.4900    20.8800                     26.90      20.8800
#
#    Current_Price  Recommended_New_Price
# 0          38.90                  41.42
# 1          33.90                  34.11
# 2          34.90                  38.51
# 3          29.90                  33.27
# 4          21.90                   0.00
# 5          14.95                  19.79
# 6          34.90                  38.31
# 7          29.90                  35.97
# 8          14.90                  20.55
# 9          19.90                  22.32

# %%
df['Highest_Competitor_Price'] = (
    df['Highest_Competitor_Price']
    .astype(str)
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    .str.strip()
)

df['Highest_Competitor_Price'] = pd.to_numeric(
    df['Highest_Competitor_Price'],
    errors='coerce'
)

# %%
df.columns
# Out:
# Index(['SKU', 'Product_description', 'Product Role', 'Country_of_Origin',
#        'FBA Fee', 'Storage Fee', 'Handling_Cost', 'Cost', 'Current_Price',
#        'Minimum_Acceptable_Margin_%', 'Target_Gross_Margin_%',
#        'Minimum_margin', 'Sessions - Total', 'Units Ordered',
#        'Ordered Product Sales', 'Total Order Items', 'demand_signal',
#        'days-of-supply', 'inventory_signal', 'spend', 'acosClicks7d',
#        'ads_signal', 'Highest_Competitor_Price', 'price_bucket',
#        'True_Unit_Cost', 'Floor_Price', 'min_price', 'target_price',
#        'Recommended_New_Price'],
#       dtype='object')

# %%
df[['Highest_Competitor_Price']].dtypes
# Out:
# Highest_Competitor_Price    float64
# dtype: object

# %%
## EDA VISUALIZATION (Eploratory data analysis )
## 1. pricing decisions require direct comparison between current and recommended prices at the SKU level.

# %%
# Ensure SKU-level data
df_plot = df.sort_values("SKU")

x = np.arange(len(df_plot))
bar_width = 0.4

plt.figure(figsize=(10, 5))

# Current Price
plt.bar(
    x - bar_width/2,
    df_plot["Current_Price"],
    bar_width,
    label="Current Price"
)

# Recommended Price
plt.bar(
    x + bar_width/2,
    df_plot["Recommended_New_Price"],
    bar_width,
    label="Recommended Price"
)

plt.xlabel("SKU")
plt.ylabel("Price")
plt.title("Current Price vs Recommended Price by SKU")
plt.xticks(x, df_plot["SKU"], rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Create price buckets
df["price_bucket"] = pd.qcut(df["Current_Price"], q=5, duplicates="drop")

# Aggregate margin by price bucket
bucket_margin = (
    df.groupby("price_bucket")["Gross_Margin_%"]
      .mean()
      .reset_index()
)

plt.figure(figsize=(8, 5))

plt.plot(
    bucket_margin["price_bucket"].astype(str),
    bucket_margin["Gross_Margin_%"],
    marker="o"
)

plt.xlabel("Price Bucket")
plt.ylabel("Average Gross Margin %")
plt.title("Average Gross Margin % by Price Level")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\saranya cj\AppData\Local\Temp\ipykernel_14740\3102177746.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("price_bucket")["Gross_Margin_%"]

# %%
df["Gross_Margin_$"] = df["Current_Price"] - df["True_Unit_Cost"]
df["Gross_Margin_%"] = df["Gross_Margin_$"] / df["Current_Price"]
df.head
# Out:
# <bound method NDFrame.head of       SKU                       Product_description Product Role  \
# 0   MN-01  Rectangle Tray -14 x 10 Inch - Pk of  25         Core
# 1   MN-02          Rectangle Tray -12x10 - Pk of 25         Core
# 2   MN-03         Oval Tray -15x10 Inch - Pk of  25         Core
# 3   MN-04          Oval Tray - 13x9 Inch - pk of 25         Core
# 4   MN-05     Christmas Tray - 17x12 Inch - Pk of 5     Seasonal
# 5   MN-06             Star Tray - 14 Inch - Pk of 5     Seasonal
# 6   MN-07                 15 Round plate - pk of 10         Core
# 7   MN-08           10 Inch Heart Plates - pk of 25     Seasonal
# 8   MN-09            6 Inch Heart Plates - pk of 25     Seasonal
# 9   MN-10                  9x6 Rectangle - pk of 25         Core
# 10  MN-11          Oval Tray - 13x9 Inch - pk of 10         Core
# 11  MN-12       13 inch Round DEEP plate - pk of 10         Core
# 12  MN-13       14 inch Round DEEP plate - Pk of 10         Core
# 13  MN-14            12 inch Round plate - Pk of 25         Core
# 14  MN-15    Rectangle Tray -14x10 Inch - Pk of  10         Core
# 15  MN-16         Oval Tray -15x10 Inch - Pk of  10         Core
# 16  MN-17       Square Combo 10 & 7 inch - Pk of 50         Core
# 17  MN-18        Round Combo 10 & 7 inch - Pk of 50         Core
# 18  MN-19         Oval Tray - 22x12 Inch - Pk of 10         Core
# 19  MN-20            3.5 Inch round Bowl - Pk of 25         Core
# 20  MN-21               11 x 7 Rectangle - Pk of 25         Core
# 21  MN-22            13 inch Round plate - Pk of 10         Core
# 22  MN-23    2.5 Inch round Bowl - 25 ml - Pk of 25         Core
# 23  MN-24          Rectangle Tray -12x10 - pk of 10         Core
# 24  MN-25                10 inch square -  pk of 50         Core
# 25  MN-26                 8 inch square -  pk of 50         Core
# 26  MN-27                 7 inch square -  pk of 50         Core
# 27  MN-28                 6 inch square -  pk of 50         Core
# 28  MN-29                 4 inch square -  pk of 50         Core
# 29  MN-30                   10 inch Round- pk of 50         Core
# 30  MN-31                       8 Round -  pk of 50         Core
# 31  MN-32                       7 Round -  pk of 50         Core
# 32  MN-33                       6 Round -  pk of 50         Core
# 33  MN-34                       9 Square - pk of 50         Core
# 34  MN-35                       9 Round -  pk of 50         Core
# 35  MN-36              17x12 - Oval Tray - pk of 10         Core
# 36  MN-37                      11 Square - pk of 25         Core
# 37  MN-38               3.5 Round Bowl -  pk of 100         Core
# 38  MN-39               2.5 Round Bowl -  pk of 100         Core
# 39  MN-40                 5 inch square -  pk of 50         Core
# 40  MN-41                6 inch square -  pk of 200         Core
# 41  MN-42                4 inch square -  pk of 200         Core
# 42  MN-43               3.5 Square Bowl -  Pk of 25         Core
# 43  MN-44                2.5 Square Bowl - Pk of 25         Core
# 44  MN-45              3.5 Square Bowl -  Pk of 100         Core
# 45  MN-46               2.5 Square Bowl - Pk of 100         Core
# 46  MN-47                5 inch square -  pk of 200         Core
# 47  MN-48                     7 Square -  pk of 200         Core
# 48  MN-49              11 x 7 Rectangle -  pk of 50         Core
# 49  MN-50                  9x6 Rectangle - pk of 50         Core
#
#    Country_of_Origin  FBA Fee  Storage Fee  Handling_Cost  Cost  \
# 0              India    15.11         0.44           0.75  16.0
# 1              India    13.55         0.30           0.75  12.0
# 2              India    13.94         0.34           0.75  15.0
# 3              India    12.89         0.30           0.75  12.0
# 4              India    11.80         0.22           0.75  13.0
# 5              India     8.50         0.12           0.75   5.0
# 6              India    17.85         0.27           0.75  11.0
# 7              India    12.11         0.25           0.75  13.0
# 8              India     8.08         0.09           0.75   6.0
# 9              India     9.52         0.13           0.75   7.0
# 10             India     9.36         0.15           0.75   5.0
# 11             India    10.90         0.22           0.75   6.0
# 12             India     9.97         0.08           0.75   7.0
# 13             India    12.82         0.36           0.75  11.0
# 14             India    11.29         0.20           0.75   7.0
# 15             India    10.46         0.19           0.75   6.0
# 16             India    12.89         0.34           0.75  14.0
# 17             India    12.61         0.37           0.75  14.0
# 18             India    19.68         0.51           0.75  12.0
# 19             India     6.24         0.03           0.75   4.0
# 20             India    10.46         0.19           0.75   8.0
# 21             India    11.12         0.21           0.75   7.0
# 22             India     5.64         0.01           0.75   4.0
# 23             India     9.72         0.15           0.75   5.0
# 24             India    14.05         0.41           0.75  16.0
# 25             India    12.87         0.23           0.75  13.0
# 26             India    12.20         0.23           0.75  11.0
# 27             India    10.56         0.16           0.75  11.0
# 28             India     8.89         0.07           0.75   8.0
# 29             India    18.10         0.38           0.75  16.0
# 30             India    12.56         0.24           0.75  13.0
# 31             India    11.96         0.20           0.75  11.0
# 32             India    10.27         0.14           0.75  11.0
# 33             India    13.41         0.28           0.75  14.0
# 34             India    13.41         0.33           0.75  14.0
# 35             India    13.03         0.27           0.75  11.0
# 36             India    11.96         0.21           0.75  13.0
# 37             India    11.41         0.13           0.00  14.0
# 38             India     9.11         0.07           0.75  13.0
# 39             India     9.81         0.11           0.75   9.0
# 40             India    21.15         0.52           0.75  41.0
# 41             India    18.74         0.30           0.75  31.0
# 42             India     6.03         0.03           0.75   4.0
# 43             India     5.88         0.03           0.75   3.0
# 44             India    10.85         0.08           0.75  14.0
# 45             India     9.17         0.07           0.75  11.0
# 46             India    20.21         0.38           0.75  34.0
# 47             India    23.50         0.73           0.75  44.0
# 48             India    13.51         0.30           0.75  16.0
# 49             India    12.58         0.27           0.75  14.0
#
#     Current_Price  Minimum_Acceptable_Margin_%  ...  Highest_Competitor_Price  \
# 0           38.90                         20.0  ...                     44.90
# 1           33.90                         20.0  ...                     39.95
# 2           34.90                         20.0  ...                     42.50
# 3           29.90                         20.0  ...                     35.90
# 4           21.90                         25.0  ...                      0.00
# 5           14.95                         25.0  ...                     21.50
# 6           34.90                         20.0  ...                     41.95
# 7           29.90                         25.0  ...                     39.90
# 8           14.90                         25.0  ...                     22.90
# 9           19.90                         20.0  ...                     26.90
# 10          16.90                         20.0  ...                     23.50
# 11          19.90                         20.0  ...                     27.90
# 12          22.90                         20.0  ...                     31.50
# 13          26.90                         20.0  ...                     35.90
# 14          21.90                         20.0  ...                     29.90
# 15          19.90                         20.0  ...                     26.50
# 16          29.90                         20.0  ...                     39.90
# 17          26.90                         20.0  ...                     36.90
# 18          36.90                         20.0  ...                     49.90
# 19          11.90                         20.0  ...                     16.90
# 20          21.90                         20.0  ...                     29.90
# 21          20.90                         20.0  ...                     27.90
# 22           9.95                         20.0  ...                     14.90
# 23          19.90                         20.0  ...                     26.90
# 24          34.90                         20.0  ...                     44.90
# 25          29.90                         20.0  ...                     38.90
# 26          28.90                         20.0  ...                     37.90
# 27          24.90                         20.0  ...                     33.90
# 28          21.90                         20.0  ...                     29.90
# 29          34.90                         20.0  ...                     45.90
# 30          28.90                         20.0  ...                     37.90
# 31          26.90                         20.0  ...                     34.90
# 32          25.90                         20.0  ...                     33.90
# 33          32.90                         20.0  ...                     42.90
# 34          31.90                         20.0  ...                     41.90
# 35          29.90                         20.0  ...                     37.90
# 36          28.90                         20.0  ...                     36.90
# 37          29.90                         20.0  ...                     39.90
# 38          24.90                         20.0  ...                     32.90
# 39          23.90                         20.0  ...                     31.90
# 40          78.90                         20.0  ...                     99.90
# 41          73.90                         20.0  ...                     94.90
# 42          13.90                         20.0  ...                     19.90
# 43          11.90                         20.0  ...                     17.90
# 44          29.90                         20.0  ...                     39.90
# 45          26.90                         20.0  ...                     36.90
# 46          76.90                         20.0  ...                     98.90
# 47          89.90                         20.0  ...                    109.90
# 48          32.90                         20.0  ...                     41.90
# 49          29.90                         20.0  ...                     38.90
#
#      price_bucket  True_Unit_Cost  Floor_Price  min_price  target_price  \
# 0    (34.1, 89.9]           32.30      38.7600    38.7600       43.6050
# 1    (29.9, 34.1]           26.60      31.9200    31.9200       35.9100
# 2    (34.1, 89.9]           30.03      36.0360    36.0360       40.5405
# 3    (25.5, 29.9]           25.94      31.1280    31.1280       35.0190
# 4    (19.9, 25.5]           25.77      32.2125    32.2125       37.3665
# 5   (9.949, 19.9]           14.37      17.9625    17.9625       20.8365
# 6    (34.1, 89.9]           29.87      35.8440    35.8440       40.3245
# 7    (25.5, 29.9]           26.11      32.6375    32.6375       37.8595
# 8   (9.949, 19.9]           14.92      18.6500    18.6500       21.6340
# 9   (9.949, 19.9]           17.40      20.8800    20.8800       23.4900
# 10  (9.949, 19.9]           15.26      18.3120    18.3120       20.6010
# 11  (9.949, 19.9]           17.87      21.4440    21.4440       24.1245
# 12   (19.9, 25.5]           17.80      21.3600    21.3600       24.0300
# 13   (25.5, 29.9]           24.93      29.9160    29.9160       33.6555
# 14   (19.9, 25.5]           19.24      23.0880    23.0880       25.9740
# 15  (9.949, 19.9]           17.40      20.8800    20.8800       23.4900
# 16   (25.5, 29.9]           27.98      33.5760    33.5760       37.7730
# 17   (25.5, 29.9]           27.73      33.2760    33.2760       37.4355
# 18   (34.1, 89.9]           32.94      39.5280    39.5280       44.4690
# 19  (9.949, 19.9]           11.02      13.2240    13.2240       14.8770
# 20   (19.9, 25.5]           19.40      23.2800    23.2800       26.1900
# 21   (19.9, 25.5]           19.08      22.8960    22.8960       25.7580
# 22  (9.949, 19.9]           10.40      12.4800    12.4800       14.0400
# 23  (9.949, 19.9]           15.62      18.7440    18.7440       21.0870
# 24   (34.1, 89.9]           31.21      37.4520    37.4520       42.1335
# 25   (25.5, 29.9]           26.85      32.2200    32.2200       36.2475
# 26   (25.5, 29.9]           24.18      29.0160    29.0160       32.6430
# 27   (19.9, 25.5]           22.47      26.9640    26.9640       30.3345
# 28   (19.9, 25.5]           17.71      21.2520    21.2520       23.9085
# 29   (34.1, 89.9]           35.23      42.2760    42.2760       47.5605
# 30   (25.5, 29.9]           26.55      31.8600    31.8600       35.8425
# 31   (25.5, 29.9]           23.91      28.6920    28.6920       32.2785
# 32   (25.5, 29.9]           22.16      26.5920    26.5920       29.9160
# 33   (29.9, 34.1]           28.44      34.1280    34.1280       38.3940
# 34   (29.9, 34.1]           28.49      34.1880    34.1880       38.4615
# 35   (25.5, 29.9]           25.05      30.0600    30.0600       33.8175
# 36   (25.5, 29.9]           25.92      31.1040    31.1040       34.9920
# 37   (25.5, 29.9]           25.54      30.6480    30.6480       34.4790
# 38   (19.9, 25.5]           22.93      27.5160    27.5160       30.9555
# 39   (19.9, 25.5]           19.67      23.6040    23.6040       26.5545
# 40   (34.1, 89.9]           63.42      76.1040    76.1040       85.6170
# 41   (34.1, 89.9]           50.79      60.9480    60.9480       68.5665
# 42  (9.949, 19.9]           10.81      12.9720    12.9720       14.5935
# 43  (9.949, 19.9]            9.66      11.5920    11.5920       13.0410
# 44   (25.5, 29.9]           25.68      30.8160    30.8160       34.6680
# 45   (25.5, 29.9]           20.99      25.1880    25.1880       28.3365
# 46   (34.1, 89.9]           55.34      66.4080    66.4080       74.7090
# 47   (34.1, 89.9]           68.98      82.7760    82.7760       93.1230
# 48   (29.9, 34.1]           30.56      36.6720    36.6720       41.2560
# 49   (25.5, 29.9]           27.60      33.1200    33.1200       37.2600
#
#    Recommended_New_Price  Price_Difference Gross_Margin_$  Gross_Margin_%
# 0                  41.42              2.52           6.60        0.169666
# 1                  34.11              0.21           7.30        0.215339
# 2                  38.51              3.61           4.87        0.139542
# 3                  33.27              3.37           3.96        0.132441
# 4                   0.00            -21.90          -3.87       -0.176712
# 5                  19.79              4.84           0.58        0.038796
# 6                  38.31              3.41           5.03        0.144126
# 7                  35.97              6.07           3.79        0.126756
# 8                  20.55              5.65          -0.02       -0.001342
# 9                  22.32              2.42           2.50        0.125628
# 10                 19.57              2.67           1.64        0.097041
# 11                 22.92              3.02           2.03        0.102010
# 12                 22.83             -0.07           5.10        0.222707
# 13                 31.97              5.07           1.97        0.073234
# 14                 24.68              2.78           2.66        0.121461
# 15                 22.32              2.42           2.50        0.125628
# 16                 35.88              5.98           1.92        0.064214
# 17                 35.56              8.66          -0.83       -0.030855
# 18                 42.25              5.35           3.96        0.107317
# 19                 14.13              2.23           0.88        0.073950
# 20                 24.88              2.98           2.50        0.114155
# 21                 24.47              3.57           1.82        0.087081
# 22                 13.34              3.39          -0.45       -0.045226
# 23                 20.03              0.13           4.28        0.215075
# 24                 40.03              5.13           3.69        0.105731
# 25                 34.44              4.54           3.05        0.102007
# 26                 31.01              2.11           4.72        0.163322
# 27                 28.82              3.92           2.43        0.097590
# 28                 22.71              0.81           4.19        0.191324
# 29                 45.18             10.28          -0.33       -0.009456
# 30                 34.05              5.15           2.35        0.081315
# 31                 30.66              3.76           2.99        0.111152
# 32                 28.42              2.52           3.74        0.144402
# 33                 36.47              3.57           4.46        0.135562
# 34                 36.54              4.64           3.41        0.106897
# 35                 32.13              2.23           4.85        0.162207
# 36                 33.24              4.34           2.98        0.103114
# 37                 32.76              2.86           4.36        0.145819
# 38                 29.41              4.51           1.97        0.079116
# 39                 25.23              1.33           4.23        0.176987
# 40                 81.34              2.44          15.48        0.196198
# 41                 65.14             -8.76          23.11        0.312720
# 42                 13.86             -0.04           3.09        0.222302
# 43                 12.39              0.49           2.24        0.188235
# 44                 32.93              3.03           4.22        0.141137
# 45                 26.92              0.02           5.91        0.219703
# 46                 70.97             -5.93          21.56        0.280364
# 47                 88.47             -1.43          20.92        0.232703
# 48                 39.19              6.29           2.34        0.071125
# 49                 35.40              5.50           2.30        0.076923
#
# [50 rows x 32 columns]>

# %%
plot_df = df[['SKU',
              'target_price',
              'Floor_Price',
              'Recommended_New_Price',
              'Highest_Competitor_Price']].head(5)

# %%
x = np.arange(len(plot_df))
width = 0.2

plt.figure(figsize=(10, 5))

plt.bar(x - 1.5*width, plot_df['Floor_Price'], width, label='Floor Price')
plt.bar(x - 0.5*width, plot_df['target_price'], width, label='Target Price')
plt.bar(x + 0.5*width, plot_df['Recommended_New_Price'], width, label='Recommended Price')
plt.bar(x + 1.5*width, plot_df['Highest_Competitor_Price'], width, label='Highest Competitor Price')

plt.xticks(x, plot_df['SKU'], rotation=45)
plt.ylabel('Price')
plt.title('SKU-level Pricing Comparison')
plt.legend()
plt.tight_layout()
plt.show()

# %%
##All SKUs now respect competitor pricing guardrails

(df['Recommended_New_Price'] <= df['Highest_Competitor_Price']).all()
# Out:
# np.True_

# %%
df["Price_Difference"] = df["Recommended_New_Price"] - df["Current_Price"]
df[["SKU", "Current_Price", "Recommended_New_Price", "Price_Difference"]].head(10)
# Out:
#      SKU  Current_Price  Recommended_New_Price  Price_Difference
# 0  MN-01          38.90                  41.42              2.52
# 1  MN-02          33.90                  34.11              0.21
# 2  MN-03          34.90                  38.51              3.61
# 3  MN-04          29.90                  33.27              3.37
# 4  MN-05          21.90                   0.00            -21.90
# 5  MN-06          14.95                  19.79              4.84
# 6  MN-07          34.90                  38.31              3.41
# 7  MN-08          29.90                  35.97              6.07
# 8  MN-09          14.90                  20.55              5.65
# 9  MN-10          19.90                  22.32              2.42

# %%
df.to_excel("pricing_dashboard_data.xlsx", index=False)

# %%
df.head()
# Out:
#      SKU                       Product_description Product Role  \
# 0  MN-01  Rectangle Tray -14 x 10 Inch - Pk of  25         Core
# 1  MN-02          Rectangle Tray -12x10 - Pk of 25         Core
# 2  MN-03         Oval Tray -15x10 Inch - Pk of  25         Core
# 3  MN-04          Oval Tray - 13x9 Inch - pk of 25         Core
# 4  MN-05     Christmas Tray - 17x12 Inch - Pk of 5     Seasonal
#
#   Country_of_Origin FBA Fee Storage Fee Handling_Cost  Cost  Current_Price  \
# 0             India  $15.11       $0.44         $0.75  16.0           38.9
# 1             India  $13.55       $0.30         $0.75  12.0           33.9
# 2             India  $13.94       $0.34         $0.75  15.0           34.9
# 3             India  $12.89       $0.30         $0.75  12.0           29.9
# 4             India  $11.80       $0.22         $0.75  13.0           21.9
#
#   Minimum_Acceptable_Margin_%  ... Ordered Product Sales  Total Order Items  \
# 0                         20%  ...              24582.01              475.0
# 1                         20%  ...              15678.89              326.0
# 2                         20%  ...               7340.65              152.0
# 3                         20%  ...               6002.72              126.0
# 4                         25%  ...               8040.18              302.0
#
#    demand_signal  days-of-supply  inventory_signal    spend acosClicks7d  \
# 0           high            47.0         overstock  2762.06    31.491089
# 1            low            85.0         overstock  2286.92    17.450712
# 2            low            83.0         overstock   670.20    14.699685
# 3            low            99.0         overstock   903.79    38.972894
# 4            low           145.0         overstock   637.85    28.954224
#
#     ads_signal Highest_Competitor_Price  price_bucket
# 0  inefficient                    44.90  (34.1, 89.9]
# 1    efficient                    39.95  (29.9, 34.1]
# 2    efficient                    42.50  (34.1, 89.9]
# 3  inefficient                    35.90  (25.5, 29.9]
# 4  inefficient                     0.00  (19.9, 25.5]
#
# [5 rows x 24 columns]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\saranya cj'

# %%
df["Highest_Competitor_Price"] = df["Highest_Competitor_Price"].replace(0, np.nan)

# %%
## Optional Create SKU-Level Pricing ACTION Table

# %%
def pricing_action(row):
    if row["Current_Price"] < row["Floor_Price"]:
        return "Corrective Increase"
    elif row["Recommended_New_Price"] > row["Current_Price"]:
        return "Controlled Increase"
    elif row["Recommended_New_Price"] < row["Current_Price"]:
        return "Decrease"
    else:
        return "Maintain"

# %%
df["Pricing_Action"] = df.apply(pricing_action, axis=1)

# %%
pricing_actions_table = df[[
    "SKU",
    "Current_Price",
    "target_price",
    "Floor_Price",
    "Recommended_New_Price",
    "Pricing_Action"
]]

pricing_actions_table
# Out:
#       SKU  Current_Price  target_price  Floor_Price  Recommended_New_Price  \
# 0   MN-01          38.90       43.6050      38.7600                  41.42
# 1   MN-02          33.90       35.9100      31.9200                  34.11
# 2   MN-03          34.90       40.5405      36.0360                  38.51
# 3   MN-04          29.90       35.0190      31.1280                  33.27
# 4   MN-05          21.90       37.3665      32.2125                   0.00
# 5   MN-06          14.95       20.8365      17.9625                  19.79
# 6   MN-07          34.90       40.3245      35.8440                  38.31
# 7   MN-08          29.90       37.8595      32.6375                  35.97
# 8   MN-09          14.90       21.6340      18.6500                  20.55
# 9   MN-10          19.90       23.4900      20.8800                  22.32
# 10  MN-11          16.90       20.6010      18.3120                  19.57
# 11  MN-12          19.90       24.1245      21.4440                  22.92
# 12  MN-13          22.90       24.0300      21.3600                  22.83
# 13  MN-14          26.90       33.6555      29.9160                  31.97
# 14  MN-15          21.90       25.9740      23.0880                  24.68
# 15  MN-16          19.90       23.4900      20.8800                  22.32
# 16  MN-17          29.90       37.7730      33.5760                  35.88
# 17  MN-18          26.90       37.4355      33.2760                  35.56
# 18  MN-19          36.90       44.4690      39.5280                  42.25
# 19  MN-20          11.90       14.8770      13.2240                  14.13
# 20  MN-21          21.90       26.1900      23.2800                  24.88
# 21  MN-22          20.90       25.7580      22.8960                  24.47
# 22  MN-23           9.95       14.0400      12.4800                  13.34
# 23  MN-24          19.90       21.0870      18.7440                  20.03
# 24  MN-25          34.90       42.1335      37.4520                  40.03
# 25  MN-26          29.90       36.2475      32.2200                  34.44
# 26  MN-27          28.90       32.6430      29.0160                  31.01
# 27  MN-28          24.90       30.3345      26.9640                  28.82
# 28  MN-29          21.90       23.9085      21.2520                  22.71
# 29  MN-30          34.90       47.5605      42.2760                  45.18
# 30  MN-31          28.90       35.8425      31.8600                  34.05
# 31  MN-32          26.90       32.2785      28.6920                  30.66
# 32  MN-33          25.90       29.9160      26.5920                  28.42
# 33  MN-34          32.90       38.3940      34.1280                  36.47
# 34  MN-35          31.90       38.4615      34.1880                  36.54
# 35  MN-36          29.90       33.8175      30.0600                  32.13
# 36  MN-37          28.90       34.9920      31.1040                  33.24
# 37  MN-38          29.90       34.4790      30.6480                  32.76
# 38  MN-39          24.90       30.9555      27.5160                  29.41
# 39  MN-40          23.90       26.5545      23.6040                  25.23
# 40  MN-41          78.90       85.6170      76.1040                  81.34
# 41  MN-42          73.90       68.5665      60.9480                  65.14
# 42  MN-43          13.90       14.5935      12.9720                  13.86
# 43  MN-44          11.90       13.0410      11.5920                  12.39
# 44  MN-45          29.90       34.6680      30.8160                  32.93
# 45  MN-46          26.90       28.3365      25.1880                  26.92
# 46  MN-47          76.90       74.7090      66.4080                  70.97
# 47  MN-48          89.90       93.1230      82.7760                  88.47
# 48  MN-49          32.90       41.2560      36.6720                  39.19
# 49  MN-50          29.90       37.2600      33.1200                  35.40
#
#          Pricing_Action
# 0   Controlled Increase
# 1   Controlled Increase
# 2   Corrective Increase
# 3   Corrective Increase
# 4   Corrective Increase
# 5   Corrective Increase
# 6   Corrective Increase
# 7   Corrective Increase
# 8   Corrective Increase
# 9   Corrective Increase
# 10  Corrective Increase
# 11  Corrective Increase
# 12             Decrease
# 13  Corrective Increase
# 14  Corrective Increase
# 15  Corrective Increase
# 16  Corrective Increase
# 17  Corrective Increase
# 18  Corrective Increase
# 19  Corrective Increase
# 20  Corrective Increase
# 21  Corrective Increase
# 22  Corrective Increase
# 23  Controlled Increase
# 24  Corrective Increase
# 25  Corrective Increase
# 26  Corrective Increase
# 27  Corrective Increase
# 28  Controlled Increase
# 29  Corrective Increase
# 30  Corrective Increase
# 31  Corrective Increase
# 32  Corrective Increase
# 33  Corrective Increase
# 34  Corrective Increase
# 35  Corrective Increase
# 36  Corrective Increase
# 37  Corrective Increase
# 38  Corrective Increase
# 39  Controlled Increase
# 40  Controlled Increase
# 41             Decrease
# 42             Decrease
# 43  Controlled Increase
# 44  Corrective Increase
# 45  Controlled Increase
# 46             Decrease
# 47             Decrease
# 48  Corrective Increase
# 49  Corrective Increase

# %%
# matrix table

# %%
decision_matrix = pd.DataFrame({
    "Below Floor (Unsafe)": [
        "Corrective Increase",
        "Corrective Increase",
        "Corrective Increase"
    ],
    "Above Floor (Safe)": [
        "Controlled Increase",
        "Maintain",
        "Decrease"
    ]
}, index=["Underpriced", "At Target", "Overpriced"])

decision_matrix
# Out:
#             Below Floor (Unsafe)   Above Floor (Safe)
# Underpriced  Corrective Increase  Controlled Increase
# At Target    Corrective Increase             Maintain
# Overpriced   Corrective Increase             Decrease
